# %%
import os
import tiledb
import tiledb.cloud
import tiledb.cloud.utilities
import tiledbvcf
import numpy as np
import pandas as pd

print(
    f"tiledb v{tiledb.version.version}\n"
    f"tiledb-vcf v{tiledbvcf.version}\n"
    f"tiledb-cloud v{tiledb.cloud.version.version}\n"
)

# Create a base config, if you have aws credentials configured we can automically use them for ingestion
#config = tiledb.cloud.utilities.read_aws_config()
# Out:
# tiledb v0.23.2
# tiledb-vcf v0.26.2
# tiledb-cloud v0.11.0

# %%
config = tiledb.Config()
config["vfs.s3.aws_access_key_id"] = "####################"
config["vfs.s3.aws_secret_access_key"] = "####################################"
config["vfs.s3.region"] = "us-east-1"
vfs = tiledb.VFS(config=config)

# %% [markdown]
# ## Query the gene_based array

# %%
#Have to first copy the array created locally to s3 by running the following line
#aws s3 --profile insight cp ukb_ancestry_array s3://tak-insight-priv-tiledb-plat/arrays/ukb_ancestry_array --recursive

# %%
# %%time
array_uri = "s3://tak-insight-open-geneshealthconsort-silv/tiledb_array/GNH_2023_02_44kCallset_qt_gene_based/"
with tiledb.open(array_uri, mode="r", ctx=tiledb.Ctx(config)) as A:
    print(A.schema)
# Out:
# ArraySchema(
#   domain=Domain(*[
#     Dim(name='Gene ID', domain=('', ''), tile=None, dtype='|S0', var=True, filters=FilterList([ZstdFilter(level=-1), ])),
#     Dim(name='Phenotype', domain=('', ''), tile=None, dtype='|S0', var=True, filters=FilterList([ZstdFilter(level=-1), ])),
#   ]),
#   attrs=[
#     Attr(name='CHROM', dtype='int64', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='GENPOS', dtype='int64', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='ID', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='ALLELE0', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Mask', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='A1FREQ', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='N', dtype='int64', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='TEST', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='BETA', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='SE', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='CHISQ', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='LOG10P', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Gene Symbol', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Variant Mask', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Freq', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Raw Path', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Stat', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Gene-based', dtype='bool', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Female-only', dtype='bool', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Male-only', dtype='bool', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Label', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#   ],
#   cell_order='row-major',
#   tile_order='row-major',
#   capacity=10000,
#   sparse=True,
#   allows_duplicates=True,
# )
#
# CPU times: user 71.5 ms, sys: 24.4 ms, total: 95.9 ms
# Wall time: 258 ms

# %% [markdown]
# ### Query for all results for a given gene (TYK2)

# %%
# %%time
with tiledb.open(array_uri, mode="r", ctx=tiledb.Ctx(config)) as A:
    print(A.df['ENSG00000105397',:])
# Out:
#                                   CHROM    GENPOS  \
# Gene ID         Phenotype
# ENSG00000105397 AFP                  19  10350840
#                 AFP                  19  10350840
#                 AFP                  19  10350840
#                 AFP                  19  10350840
#                 AFP                  19  10350840
# ...                                 ...       ...
#                 urine_creatinine     19  10350840
#                 urine_creatinine     19  10350840
#                 urine_creatinine     19  10350840
#                 urine_creatinine     19  10350840
#                 urine_creatinine     19  10350840
#
#                                                                       ID  \
# Gene ID         Phenotype
# ENSG00000105397 AFP                   TYK2(ENSG00000105397).MASK_C.0.001
#                 AFP               TYK2(ENSG00000105397).MASK_B.singleton
#                 AFP                   TYK2(ENSG00000105397).MASK_B.0.001
#                 AFP                   TYK2(ENSG00000105397).MASK_B.0.001
#                 AFP                   TYK2(ENSG00000105397).MASK_B.0.001
# ...                                                                  ...
#                 urine_creatinine  TYK2(ENSG00000105397).MASK_B.singleton
#                 urine_creatinine     TYK2(ENSG00000105397).MASK_A.0.0001
#                 urine_creatinine      TYK2(ENSG00000105397).MASK_A.0.001
#                 urine_creatinine      TYK2(ENSG00000105397).MASK_A.0.001
#                 urine_creatinine      TYK2(ENSG00000105397).MASK_A.0.001
#
#                                  ALLELE0         Mask       A1FREQ      N  \
# Gene ID         Phenotype
# ENSG00000105397 AFP                  ref      C.0.001                 478
#                 AFP                  ref  B.singleton    0.0115063    478
#                 AFP                  ref      B.0.001    0.0115063    478
#                 AFP                  ref      B.0.001                 478
#                 AFP                  ref      B.0.001                 478
# ...                                  ...          ...          ...    ...
#                 urine_creatinine     ref  B.singleton   0.00118138  12697
#                 urine_creatinine     ref     A.0.0001  0.000354414  12697
#                 urine_creatinine     ref      A.0.001               12697
#                 urine_creatinine     ref      A.0.001               12697
#                 urine_creatinine     ref      A.0.001   0.00063007  12697
#
#                                        TEST       BETA        SE  ...  \
# Gene ID         Phenotype                                         ...
# ENSG00000105397 AFP               ADD-SKATO                       ...
#                 AFP                     ADD  -0.241647  0.295582  ...
#                 AFP                     ADD  -0.241647  0.295582  ...
#                 AFP               ADD-SKATO                       ...
#                 AFP                ADD-SKAT                       ...
# ...                                     ...        ...       ...  ...
#                 urine_creatinine        ADD   0.220236  0.171729  ...
#                 urine_creatinine        ADD    0.31261  0.313213  ...
#                 urine_creatinine   ADD-SKAT                       ...
#                 urine_creatinine  ADD-SKATO                       ...
#                 urine_creatinine        ADD  0.0162753  0.235073  ...
#
#                                      LOG10P Gene Symbol Variant Mask  \
# Gene ID         Phenotype
# ENSG00000105397 AFP                0.153292        TYK2            C
#                 AFP                0.383393        TYK2            B
#                 AFP                0.383393        TYK2            B
#                 AFP                0.383393        TYK2            B
#                 AFP                0.383393        TYK2            B
# ...                                     ...         ...          ...
#                 urine_creatinine   0.699664        TYK2            B
#                 urine_creatinine   0.497241        TYK2            A
#                 urine_creatinine  0.0246589        TYK2            A
#                 urine_creatinine  0.0246589        TYK2            A
#                 urine_creatinine  0.0246589        TYK2            A
#
#                                        Freq  \
# Gene ID         Phenotype
# ENSG00000105397 AFP                   0.001
#                 AFP               singleton
#                 AFP                   0.001
#                 AFP                   0.001
#                 AFP                   0.001
# ...                                     ...
#                 urine_creatinine  singleton
#                 urine_creatinine     0.0001
#                 urine_creatinine      0.001
#                 urine_creatinine      0.001
#                 urine_creatinine      0.001
#
#                                                                            Raw Path  \
# Gene ID         Phenotype
# ENSG00000105397 AFP               tak-insight-open-geneshealthconsort-silv/raw/2...
#                 AFP               tak-insight-open-geneshealthconsort-silv/raw/2...
#                 AFP               tak-insight-open-geneshealthconsort-silv/raw/2...
#                 AFP               tak-insight-open-geneshealthconsort-silv/raw/2...
#                 AFP               tak-insight-open-geneshealthconsort-silv/raw/2...
# ...                                                                             ...
#                 urine_creatinine  tak-insight-open-geneshealthconsort-silv/raw/2...
#                 urine_creatinine  tak-insight-open-geneshealthconsort-silv/raw/2...
#                 urine_creatinine  tak-insight-open-geneshealthconsort-silv/raw/2...
#                 urine_creatinine  tak-insight-open-geneshealthconsort-silv/raw/2...
#                 urine_creatinine  tak-insight-open-geneshealthconsort-silv/raw/2...
#
#                                       Stat Gene-based  Female-only  Male-only  \
# Gene ID         Phenotype
# ENSG00000105397 AFP               residual       True        False      False
#                 AFP               residual       True        False      False
#                 AFP               residual       True        False      False
#                 AFP               residual       True        False      False
#                 AFP               residual       True        False      False
# ...                                    ...        ...          ...        ...
#                 urine_creatinine  residual       True        False      False
#                 urine_creatinine  residual       True        False      False
#                 urine_creatinine  residual       True        False      False
#                 urine_creatinine  residual       True        False      False
#                 urine_creatinine  residual       True        False      False
#
#                                                           Label
# Gene ID         Phenotype
# ENSG00000105397 AFP                            AFP (gene-based)
#                 AFP                            AFP (gene-based)
#                 AFP                            AFP (gene-based)
#                 AFP                            AFP (gene-based)
#                 AFP                            AFP (gene-based)
# ...                                                         ...
#                 urine_creatinine  urine creatinine (gene-based)
#                 urine_creatinine  urine creatinine (gene-based)
#                 urine_creatinine  urine creatinine (gene-based)
#                 urine_creatinine  urine creatinine (gene-based)
#                 urine_creatinine  urine creatinine (gene-based)
#
# [1668 rows x 21 columns]
# CPU times: user 1.53 s, sys: 539 ms, total: 2.07 s
# Wall time: 1.7 s

# %% [markdown]
# ### Query for all signigicant burden associations for a given trait (Bilirubin)

# %%
# %%time
with tiledb.open(array_uri, mode="r", ctx=tiledb.Ctx(config)) as A:
    print(A.df[:,'Bilirubin'])
# Out:
#                            CHROM     GENPOS  \
# Gene ID         Phenotype
# ENSG00000000419 Bilirubin     20   50935148
#                 Bilirubin     20   50935148
#                 Bilirubin     20   50935148
#                 Bilirubin     20   50935148
#                 Bilirubin     20   50935148
# ...                          ...        ...
# ENSG00000288705 Bilirubin      2  233712995
#                 Bilirubin      2  233712995
#                 Bilirubin      2  233712995
#                 Bilirubin      2  233712995
#                 Bilirubin      2  233712995
#
#                                                                  ID ALLELE0  \
# Gene ID         Phenotype
# ENSG00000000419 Bilirubin        DPM1(ENSG00000000419).MASK_A.0.001     ref
#                 Bilirubin         DPM1(ENSG00000000419).MASK_D.0.01     ref
#                 Bilirubin        DPM1(ENSG00000000419).MASK_D.0.001     ref
#                 Bilirubin        DPM1(ENSG00000000419).MASK_D.0.001     ref
#                 Bilirubin        DPM1(ENSG00000000419).MASK_D.0.001     ref
# ...                                                             ...     ...
# ENSG00000288705 Bilirubin      UGT1A5(ENSG00000288705).MASK_A.0.001     ref
#                 Bilirubin      UGT1A5(ENSG00000288705).MASK_A.0.001     ref
#                 Bilirubin     UGT1A5(ENSG00000288705).MASK_A.0.0001     ref
#                 Bilirubin  UGT1A5(ENSG00000288705).MASK_D.singleton     ref
#                 Bilirubin     UGT1A5(ENSG00000288705).MASK_D.0.0001     ref
#
#                                   Mask       A1FREQ      N       TEST  \
# Gene ID         Phenotype
# ENSG00000000419 Bilirubin      A.0.001  0.000254372  31450        ADD
#                 Bilirubin       D.0.01  0.000476948  31450        ADD
#                 Bilirubin      D.0.001  0.000476948  31450        ADD
#                 Bilirubin      D.0.001               31450  ADD-SKATO
#                 Bilirubin      D.0.001               31450   ADD-SKAT
# ...                                ...          ...    ...        ...
# ENSG00000288705 Bilirubin      A.0.001               31450  ADD-SKATO
#                 Bilirubin      A.0.001               31450   ADD-SKAT
#                 Bilirubin     A.0.0001  0.000238474  31450        ADD
#                 Bilirubin  D.singleton  0.000397456  31450        ADD
#                 Bilirubin     D.0.0001   0.00136725  31450        ADD
#
#                                 BETA        SE  ...     LOG10P Gene Symbol  \
# Gene ID         Phenotype                       ...
# ENSG00000000419 Bilirubin  0.0935519  0.209515  ...    0.18361        DPM1
#                 Bilirubin  0.0252424  0.153142  ...  0.0609415        DPM1
#                 Bilirubin  0.0252424  0.153142  ...  0.0609415        DPM1
#                 Bilirubin                       ...  0.0609415        DPM1
#                 Bilirubin                       ...  0.0609415        DPM1
# ...                              ...       ...  ...        ...         ...
# ENSG00000288705 Bilirubin                       ...    1.13306      UGT1A5
#                 Bilirubin                       ...    1.35571      UGT1A5
#                 Bilirubin   0.303206  0.241563  ...   0.678998      UGT1A5
#                 Bilirubin   0.271214  0.187159  ...   0.831774      UGT1A5
#                 Bilirubin   0.211847  0.101001  ...    1.44429      UGT1A5
#
#                           Variant Mask       Freq  \
# Gene ID         Phenotype
# ENSG00000000419 Bilirubin            A      0.001
#                 Bilirubin            D       0.01
#                 Bilirubin            D      0.001
#                 Bilirubin            D      0.001
#                 Bilirubin            D      0.001
# ...                                ...        ...
# ENSG00000288705 Bilirubin            A      0.001
#                 Bilirubin            A      0.001
#                 Bilirubin            A     0.0001
#                 Bilirubin            D  singleton
#                 Bilirubin            D     0.0001
#
#                                                                     Raw Path  \
# Gene ID         Phenotype
# ENSG00000000419 Bilirubin  tak-insight-open-geneshealthconsort-silv/raw/2...
#                 Bilirubin  tak-insight-open-geneshealthconsort-silv/raw/2...
#                 Bilirubin  tak-insight-open-geneshealthconsort-silv/raw/2...
#                 Bilirubin  tak-insight-open-geneshealthconsort-silv/raw/2...
#                 Bilirubin  tak-insight-open-geneshealthconsort-silv/raw/2...
# ...                                                                      ...
# ENSG00000288705 Bilirubin  tak-insight-open-geneshealthconsort-silv/raw/2...
#                 Bilirubin  tak-insight-open-geneshealthconsort-silv/raw/2...
#                 Bilirubin  tak-insight-open-geneshealthconsort-silv/raw/2...
#                 Bilirubin  tak-insight-open-geneshealthconsort-silv/raw/2...
#                 Bilirubin  tak-insight-open-geneshealthconsort-silv/raw/2...
#
#                                Stat Gene-based  Female-only  Male-only  \
# Gene ID         Phenotype
# ENSG00000000419 Bilirubin  residual       True        False      False
#                 Bilirubin  residual       True        False      False
#                 Bilirubin  residual       True        False      False
#                 Bilirubin  residual       True        False      False
#                 Bilirubin  residual       True        False      False
# ...                             ...        ...          ...        ...
# ENSG00000288705 Bilirubin  residual       True        False      False
#                 Bilirubin  residual       True        False      False
#                 Bilirubin  residual       True        False      False
#                 Bilirubin  residual       True        False      False
#                 Bilirubin  residual       True        False      False
#
#                                             Label
# Gene ID         Phenotype
# ENSG00000000419 Bilirubin  Bilirubin (gene-based)
#                 Bilirubin  Bilirubin (gene-based)
#                 Bilirubin  Bilirubin (gene-based)
#                 Bilirubin  Bilirubin (gene-based)
#                 Bilirubin  Bilirubin (gene-based)
# ...                                           ...
# ENSG00000288705 Bilirubin  Bilirubin (gene-based)
#                 Bilirubin  Bilirubin (gene-based)
#                 Bilirubin  Bilirubin (gene-based)
#                 Bilirubin  Bilirubin (gene-based)
#                 Bilirubin  Bilirubin (gene-based)
#
# [356031 rows x 21 columns]
# CPU times: user 42.7 s, sys: 10.8 s, total: 53.4 s
# Wall time: 9.62 s

# %% [markdown]
# ## Query the single_variant array

# %%
# %%time
array_uri = "s3://tak-insight-open-geneshealthconsort-silv/tiledb_array/GNH_2023_02_44kCallset_qt_single_variant"
with tiledb.open(array_uri, mode="r", ctx=tiledb.Ctx(config)) as B:
    print(B.schema)
# Out:
# ArraySchema(
#   domain=Domain(*[
#     Dim(name='CHROM', domain=(-9223372036854775808, 9223372036854675807), tile=100000, dtype='int64', filters=FilterList([ZstdFilter(level=-1), ])),
#     Dim(name='GENPOS', domain=(-9223372036854775808, 9223372036854675807), tile=100000, dtype='int64', filters=FilterList([ZstdFilter(level=-1), ])),
#     Dim(name='Phenotype', domain=('', ''), tile=None, dtype='|S0', var=True, filters=FilterList([ZstdFilter(level=-1), ])),
#   ]),
#   attrs=[
#     Attr(name='ID', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='ALLELE0', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='ALLELE1', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='A1FREQ', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='N', dtype='int64', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='TEST', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='BETA', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='SE', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='CHISQ', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='LOG10P', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Raw Path', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Stat', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Gene-based', dtype='bool', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Female-only', dtype='bool', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Male-only', dtype='bool', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Label', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Bonferroni Sig', dtype='bool', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#   ],
#   cell_order='row-major',
#   tile_order='row-major',
#   capacity=10000,
#   sparse=True,
#   allows_duplicates=True,
# )
#
# CPU times: user 85.2 ms, sys: 63.1 ms, total: 148 ms
# Wall time: 208 ms

# %% [markdown]
# ### Query for all single variant associations within the genomic region of a given gene (TYK2)

# %%
variants = [
    "chr19_10350865_C_A","chr19_10350910_T_C","chr19_10350911_C_T","chr19_10350923_G_A","chr19_10350937_G_A","chr19_10351069_C_T","chr19_10351093_G_A","chr19_10351103_C_G","chr19_10351143_C_T","chr19_10351155_A_C","chr19_10351159_A_G","chr19_10352436_T_TG","chr19_10352439_G_C","chr19_10352442_G_C","chr19_10352487_C_T","chr19_10352518_G_C","chr19_10352523_T_G","chr19_10352948_C_T","chr19_10352957_C_G","chr19_10352960_G_A","chr19_10352962_T_C","chr19_10352970_G_C","chr19_10352972_G_A","chr19_10353043_T_C","chr19_10353052_G_C","chr19_10353062_G_A","chr19_10353072_G_C","chr19_10353080_C_A","chr19_10353545_C_T","chr19_10353553_A_G","chr19_10353554_G_T","chr19_10353572_T_C","chr19_10353574_C_T","chr19_10353581_G_A","chr19_10353620_C_T","chr19_10353644_C_T","chr19_10354077_T_A","chr19_10354092_G_A","chr19_10354141_C_T","chr19_10354167_G_A","chr19_10354210_A_G","chr19_10354222_T_A","chr19_10354511_C_T","chr19_10354517_C_T","chr19_10354520_G_T","chr19_10354559_T_C","chr19_10354563_G_T","chr19_10354565_C_CCGA","chr19_10354579_T_C","chr19_10354593_C_A","chr19_10354598_C_T","chr19_10356582_C_T","chr19_10356583_G_A","chr19_10356606_C_
# 19_10378397_G_A   19  10378397   G   A
#
# [258 rows x 4 columns]

# %%
# %%time
#query all variants within TYK2
with tiledb.open(array_uri, mode="r", ctx=tiledb.Ctx(config)) as A:
    array = []
    for chrom,group in v_df.groupby('chr'):
        positions = sorted(list(group['pos']))
        print(chrom,len(positions))
        df1 = A.query().df[chrom,positions,:]
        array.append(df1)
            
    res = pd.concat(array,join='inner',axis=0)
    res
# Out:
# 19 258
# CPU times: user 1.61 s, sys: 828 ms, total: 2.44 s
# Wall time: 3.46 s

# %%
res
# Out:
#                                                  ID ALLELE0 ALLELE1  \
# CHROM GENPOS   Phenotype
# 19    10350910 AFP               chr19_10350910_T_C       T       C
#                ALP               chr19_10350910_T_C       T       C
#                ALT               chr19_10350910_T_C       T       C
#                APTT              chr19_10350910_T_C       T       C
#                AST               chr19_10350910_T_C       T       C
# ...                                             ...     ...     ...
#       10378397 creatinine        chr19_10378397_G_A       G       A
#                oestradiol        chr19_10378397_G_A       G       A
#                progesterone      chr19_10378397_G_A       G       A
#                testosterone      chr19_10378397_G_A       G       A
#                urine_creatinine  chr19_10378397_G_A       G       A
#
#                                       A1FREQ      N TEST        BETA  \
# CHROM GENPOS   Phenotype
# 19    10350910 AFP                 0.0219665    478  ADD    0.213802
#                ALP                 0.0205445  31590  ADD  0.00476006
#                ALT                 0.0204732  31700  ADD  -0.0531791
#                APTT                0.0193864   2966  ADD    0.126957
#                AST                 0.0169284  11844  ADD  -0.0733833
# ...                                      ...    ...  ...         ...
#       10378397 creatinine         0.00127144  32247  ADD   0.0908263
#                oestradiol         0.00118437   2533  ADD    0.682535
#                progesterone       0.00128041   2343  ADD  -0.0727316
#                testosterone      0.000971031   6179  ADD     0.12292
#                urine_creatinine   0.00149642  12697  ADD   0.0148184
#
#                                         SE       CHISQ     LOG10P  \
# CHROM GENPOS   Phenotype
# 19    10350910 AFP                0.213772     1.00027   0.498606
#                ALP               0.0264368   0.0324196  0.0669635
#                ALT               0.0241984     4.82956    1.55322
#                APTT              0.0912224     1.93692   0.785148
#                AST               0.0474843     2.38833   0.912772
# ...                                    ...         ...        ...
#       10378397 creatinine        0.0780732     1.35338   0.611387
#                oestradiol         0.402813     2.87107    1.04487
#                progesterone       0.406903   0.0319495  0.0664426
#                testosterone         0.1609     0.58362   0.351741
#                urine_creatinine   0.152583  0.00943161  0.0349706
#
#                                                                           Raw Path  \
# CHROM GENPOS   Phenotype
# 19    10350910 AFP               tak-insight-open-geneshealthconsort-silv/raw/2...
#                ALP               tak-insight-open-geneshealthconsort-silv/raw/2...
#                ALT               tak-insight-open-geneshealthconsort-silv/raw/2...
#                APTT              tak-insight-open-geneshealthconsort-silv/raw/2...
#                AST               tak-insight-open-geneshealthconsort-silv/raw/2...
# ...                                                                            ...
#       10378397 creatinine        tak-insight-open-geneshealthconsort-silv/raw/2...
#                oestradiol        tak-insight-open-geneshealthconsort-silv/raw/2...
#                progesterone      tak-insight-open-geneshealthconsort-silv/raw/2...
#                testosterone      tak-insight-open-geneshealthconsort-silv/raw/2...
#                urine_creatinine  tak-insight-open-geneshealthconsort-silv/raw/2...
#
#                                      Stat  Gene-based  Female-only  Male-only  \
# CHROM GENPOS   Phenotype
# 19    10350910 AFP               residual       False        False      False
#                ALP               residual       False        False      False
#                ALT               residual       False        False      False
#                APTT              residual       False        False      False
#                AST               residual       False        False      False
# ...                                   ...         ...          ...        ...
#       10378397 creatinine        residual       False        False      False
#                oestradiol        residual       False        False      False
#                progesterone      residual       False        False      False
#                testosterone      residual       False        False      False
#                urine_creatinine  residual       False        False      False
#
#                                             Label  Bonferroni Sig
# CHROM GENPOS   Phenotype
# 19    10350910 AFP                            AFP           False
#                ALP                            ALP           False
#                ALT                            ALT           False
#                APTT                          APTT           False
#                AST                            AST           False
# ...                                           ...             ...
#       10378397 creatinine              creatinine           False
#                oestradiol              oestradiol           False
#                progesterone          progesterone           False
#                testosterone          testosterone           False
#                urine_creatinine  urine creatinine           False
#
# [3905 rows x 17 columns]

# %% [markdown]
# ## Query the binary traits single_variant array

# %%
# %%time
array_uri = "s3://tak-insight-open-geneshealthconsort-silv/tiledb_array/GNH_2023_02_44kCallset_bin_single_variant"
with tiledb.open(array_uri, mode="r", ctx=tiledb.Ctx(config)) as B:
    print(B.schema)
# Out:
# ArraySchema(
#   domain=Domain(*[
#     Dim(name='CHROM', domain=(-9223372036854775808, 9223372036854675807), tile=100000, dtype='int64', filters=FilterList([ZstdFilter(level=-1), ])),
#     Dim(name='GENPOS', domain=(-9223372036854775808, 9223372036854675807), tile=100000, dtype='int64', filters=FilterList([ZstdFilter(level=-1), ])),
#     Dim(name='Phenotype', domain=('', ''), tile=None, dtype='|S0', var=True, filters=FilterList([ZstdFilter(level=-1), ])),
#   ]),
#   attrs=[
#     Attr(name='ID', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='ALLELE0', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='ALLELE1', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='A1FREQ', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='N', dtype='int64', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='TEST', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='BETA', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='SE', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='CHISQ', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='LOG10P', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Raw Path', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Gene-based', dtype='bool', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Phenotype Name', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Female-only', dtype='bool', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Male-only', dtype='bool', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Controls', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Label', dtype='<U0', var=True, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#     Attr(name='Bonferroni Sig', dtype='bool', var=False, nullable=False, enum_label=None, filters=FilterList([ZstdFilter(level=-1), ])),
#   ],
#   cell_order='row-major',
#   tile_order='row-major',
#   capacity=10000,
#   sparse=True,
#   allows_duplicates=True,
# )
#
# CPU times: user 97.6 ms, sys: 12.9 ms, total: 110 ms
# Wall time: 386 ms

# %% [markdown]
# ### Query for all single variant associations within the genomic region of a given gene (TYK2)

# %%
import re

variants = [
    "chr19_10350865_C_A","chr19_10350910_T_C","chr19_10350911_C_T","chr19_10350923_G_A","chr19_10350937_G_A","chr19_10351069_C_T","chr19_10351093_G_A","chr19_10351103_C_G","chr19_10351143_C_T","chr19_10351155_A_C","chr19_10351159_A_G","chr19_10352436_T_TG","chr19_10352439_G_C","chr19_10352442_G_C","chr19_10352487_C_T","chr19_10352518_G_C","chr19_10352523_T_G","chr19_10352948_C_T","chr19_10
for v in variants:
    v = re.sub(r'^chr','',v)
    parts = v.split('_')
    data['chr'].update({v: int(parts[0])})
    data['pos'].update({v: int(parts[1])})
    data['ref'].update({v: parts[2]})
    data['alt'].update({v: parts[3]})
    
v_df = pd.DataFrame.from_dict(data).dropna(subset=['chr','pos']).drop_duplicates(subset=['chr','pos'])
v_df
# Out:
#                  chr       pos ref alt
# 19_10350865_C_A   19  10350865   C   A
# 19_10350910_T_C   19  10350910   T   C
# 19_10350911_C_T   19  10350911   C   T
# 19_10350923_G_A   19  10350923   G   A
# 19_10350937_G_A   19  10350937   G   A
# ...              ...       ...  ..  ..
# 19_10378364_C_T   19  10378364   C   T
# 19_10378371_A_C   19  10378371   A   C
# 19_10378378_C_T   19  10378378   C   T
# 19_10378381_G_A   19  10378381   G   A
# 19_10378397_G_A   19  10378397   G   A
#
# [258 rows x 4 columns]

# %%
# %%time
#query all variants within TYK2
with tiledb.open(array_uri, mode="r", ctx=tiledb.Ctx(config)) as A:
    array = []
    for chrom,group in v_df.groupby('chr'):
        positions = sorted(list(group['pos']))
        print(chrom,len(positions))
        df1 = A.query().df[chrom,positions,:]
        array.append(df1)
            
    res = pd.concat(array,join='inner',axis=0)
# Out:
# 19 258
# CPU times: user 2.07 s, sys: 829 ms, total: 2.89 s
# Wall time: 5.24 s

# %%
res
# Out:
#                                                                                 ID  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                              chr19_10350910_T_C
#                A04                                              chr19_10350910_T_C
#                A05                                              chr19_10350910_T_C
#                A08                                              chr19_10350910_T_C
#                A09                                              chr19_10350910_T_C
# ...                                                                            ...
#       10378397 Venous_thromboembolism                           chr19_10378397_G_A
#                Visual_impairment_and_blindness                  chr19_10378397_G_A
#                Vitamin_B12_deficiency_with_and_without_anaemia  chr19_10378397_G_A
#                Vitiligo                                         chr19_10378397_G_A
#                Zollner_GestationalDiabetesMellitus              chr19_10378397_G_A
#
#                                                                ALLELE0  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                                   T
#                A04                                                   T
#                A05                                                   T
#                A08                                                   T
#                A09                                                   T
# ...                                                                ...
#       10378397 Venous_thromboembolism                                G
#                Visual_impairment_and_blindness                       G
#                Vitamin_B12_deficiency_with_and_without_anaemia       G
#                Vitiligo                                              G
#                Zollner_GestationalDiabetesMellitus                   G
#
#                                                                ALLELE1  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                                   C
#                A04                                                   C
#                A05                                                   C
#                A08                                                   C
#                A09                                                   C
# ...                                                                ...
#       10378397 Venous_thromboembolism                                A
#                Visual_impairment_and_blindness                       A
#                Vitamin_B12_deficiency_with_and_without_anaemia       A
#                Vitiligo                                              A
#                Zollner_GestationalDiabetesMellitus                   A
#
#                                                                     A1FREQ  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                               0.0209649
#                A04                                               0.0209649
#                A05                                               0.0209649
#                A08                                               0.0209649
#                A09                                               0.0209649
# ...                                                                    ...
#       10378397 Venous_thromboembolism                           0.00119248
#                Visual_impairment_and_blindness                  0.00119248
#                Vitamin_B12_deficiency_with_and_without_anaemia  0.00119248
#                Vitiligo                                         0.00119248
#                Zollner_GestationalDiabetesMellitus              0.00119248
#
#                                                                     N TEST  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                              44026  ADD
#                A04                                              44026  ADD
#                A05                                              44026  ADD
#                A08                                              44026  ADD
#                A09                                              44026  ADD
# ...                                                               ...  ...
#       10378397 Venous_thromboembolism                           44026  ADD
#                Visual_impairment_and_blindness                  44026  ADD
#                Vitamin_B12_deficiency_with_and_without_anaemia  44026  ADD
#                Vitiligo                                         44026  ADD
#                Zollner_GestationalDiabetesMellitus              44026  ADD
#
#                                                                       BETA  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                                0.584347
#                A04                                                0.150398
#                A05                                               -0.641005
#                A08                                               -0.182752
#                A09                                              -0.0737161
# ...                                                                    ...
#       10378397 Venous_thromboembolism                             0.396223
#                Visual_impairment_and_blindness                   0.0529151
#                Vitamin_B12_deficiency_with_and_without_anaemia   -0.534968
#                Vitiligo                                           -1.01747
#                Zollner_GestationalDiabetesMellitus               -0.177851
#
#                                                                       SE  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                              0.421951
#                A04                                              0.154348
#                A05                                              0.433729
#                A08                                              0.106676
#                A09                                              0.102079
# ...                                                                  ...
#       10378397 Venous_thromboembolism                           0.692474
#                Visual_impairment_and_blindness                  0.604107
#                Vitamin_B12_deficiency_with_and_without_anaemia  0.422832
#                Vitiligo                                         0.834045
#                Zollner_GestationalDiabetesMellitus              0.406285
#
#                                                                      CHISQ  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                                 1.91787
#                A04                                                0.949467
#                A05                                                 2.18417
#                A08                                                 2.93486
#                A09                                                0.521501
# ...                                                                    ...
#       10378397 Venous_thromboembolism                             0.327396
#                Visual_impairment_and_blindness                  0.00767241
#                Vitamin_B12_deficiency_with_and_without_anaemia     1.60074
#                Vitiligo                                            1.48821
#                Zollner_GestationalDiabetesMellitus                0.191625
#
#                                                                    LOG10P  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                               0.779652
#                A04                                               0.481677
#                A05                                               0.855624
#                A08                                                1.06205
#                A09                                               0.327715
# ...                                                                   ...
#       10378397 Venous_thromboembolism                            0.246266
#                Visual_impairment_and_blindness                  0.0314233
#                Vitamin_B12_deficiency_with_and_without_anaemia   0.686557
#                Vitiligo                                          0.652681
#                Zollner_GestationalDiabetesMellitus               0.179426
#
#                                                                                                          Raw Path  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                              tak-insight-open-geneshealthconsort-silv/raw/2...
#                A04                                              tak-insight-open-geneshealthconsort-silv/raw/2...
#                A05                                              tak-insight-open-geneshealthconsort-silv/raw/2...
#                A08                                              tak-insight-open-geneshealthconsort-silv/raw/2...
#                A09                                              tak-insight-open-geneshealthconsort-silv/raw/2...
# ...                                                                                                           ...
#       10378397 Venous_thromboembolism                           tak-insight-open-geneshealthconsort-silv/raw/2...
#                Visual_impairment_and_blindness                  tak-insight-open-geneshealthconsort-silv/raw/2...
#                Vitamin_B12_deficiency_with_and_without_anaemia  tak-insight-open-geneshealthconsort-silv/raw/2...
#                Vitiligo                                         tak-insight-open-geneshealthconsort-silv/raw/2...
#                Zollner_GestationalDiabetesMellitus              tak-insight-open-geneshealthconsort-silv/raw/2...
#
#                                                                 Gene-based  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                                   False
#                A04                                                   False
#                A05                                                   False
#                A08                                                   False
#                A09                                                   False
# ...                                                                    ...
#       10378397 Venous_thromboembolism                                False
#                Visual_impairment_and_blindness                       False
#                Vitamin_B12_deficiency_with_and_without_anaemia       False
#                Vitiligo                                              False
#                Zollner_GestationalDiabetesMellitus                   False
#
#                                                                                                    Phenotype Name  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                                             A01 Typhoid and paratyphoid fevers
#                A04                                                      A04 Other bacterial intestinal infections
#                A05                                              A05 Other bacterial foodborne intoxications, n...
#                A08                                              A08 Viral and other specified intestinal infec...
#                A09                                              A09 Other gastroenteritis and colitis of infec...
# ...                                                                                                           ...
#       10378397 Venous_thromboembolism                                                      Venous thromboembolism
#                Visual_impairment_and_blindness                                    Visual impairment and blindness
#                Vitamin_B12_deficiency_with_and_without_anaemia    Vitamin B12 deficiency with and without anaemia
#                Vitiligo                                                                                 Vitiligo
#                Zollner_GestationalDiabetesMellitus                          Zollner Gestational Diabetes Mellitus
#
#                                                                 Female-only  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                                    False
#                A04                                                    False
#                A05                                                    False
#                A08                                                    False
#                A09                                                    False
# ...                                                                     ...
#       10378397 Venous_thromboembolism                                 False
#                Visual_impairment_and_blindness                        False
#                Vitamin_B12_deficiency_with_and_without_anaemia        False
#                Vitiligo                                               False
#                Zollner_GestationalDiabetesMellitus                    False
#
#                                                                 Male-only  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                                  False
#                A04                                                  False
#                A05                                                  False
#                A08                                                  False
#                A09                                                  False
# ...                                                                   ...
#       10378397 Venous_thromboembolism                               False
#                Visual_impairment_and_blindness                      False
#                Vitamin_B12_deficiency_with_and_without_anaemia      False
#                Vitiligo                                             False
#                Zollner_GestationalDiabetesMellitus                  False
#
#                                                                Controls  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                                  All
#                A04                                                  All
#                A05                                                  All
#                A08                                                  All
#                A09                                                  All
# ...                                                                 ...
#       10378397 Venous_thromboembolism                               All
#                Visual_impairment_and_blindness                      All
#                Vitamin_B12_deficiency_with_and_without_anaemia      All
#                Vitiligo                                             All
#                Zollner_GestationalDiabetesMellitus                  All
#
#                                                                                                             Label  \
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                                             A01 Typhoid and paratyphoid fevers
#                A04                                                      A04 Other bacterial intestinal infections
#                A05                                              A05 Other bacterial foodborne intoxications, n...
#                A08                                              A08 Viral and other specified intestinal infec...
#                A09                                              A09 Other gastroenteritis and colitis of infec...
# ...                                                                                                           ...
#       10378397 Venous_thromboembolism                                                      Venous thromboembolism
#                Visual_impairment_and_blindness                                    Visual impairment and blindness
#                Vitamin_B12_deficiency_with_and_without_anaemia    Vitamin B12 deficiency with and without anaemia
#                Vitiligo                                                                                 Vitiligo
#                Zollner_GestationalDiabetesMellitus                          Zollner Gestational Diabetes Mellitus
#
#                                                                 Bonferroni Sig
# CHROM GENPOS   Phenotype
# 19    10350910 A01                                                       False
#                A04                                                       False
#                A05                                                       False
#                A08                                                       False
#                A09                                                       False
# ...                                                                        ...
#       10378397 Venous_thromboembolism                                    False
#                Visual_impairment_and_blindness                           False
#                Vitamin_B12_deficiency_with_and_without_anaemia           False
#                Vitiligo                                                  False
#                Zollner_GestationalDiabetesMellitus                       False
#
# [61126 rows x 18 columns]
