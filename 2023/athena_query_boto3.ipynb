# %%
import re
import io
import time
import numpy as np
import pandas as pd
import boto3

# %%
session = boto3.Session(profile_name='insight')
athena_client = session.client('athena')
s3_client = session.client('s3')

# %%
def wait_for_query_completion(client, query_execution_id: str):
    """      
    determines if the query has finished excuting. If it has not, the function waits for the query to finished.
    Parameters:
        query_execution_id: the query execution id (as a string)
        client: an aws client or session.client
        returns the location of query results (string)
    """
    max_execution = 600
    state = 'RUNNING'
    while (max_execution > 0 and state in ['RUNNING', 'QUEUED']):
        max_execution = max_execution - 1
        response = client.get_query_execution(QueryExecutionId = query_execution_id)
        if 'QueryExecution' in response and 'Status' in response['QueryExecution'] and 'State' in response['QueryExecution']['Status']:
            state = response['QueryExecution']['Status']['State']
            if state == 'FAILED':
                return state
            elif state == 'SUCCEEDED':
                s3_path = response['QueryExecution']['ResultConfiguration']['OutputLocation']
                return s3_path
        time.sleep(1)
    return 'FAILED'

# %%
context = {
    'Database': 'genes_and_health',
    'Catalog': 'AwsDataCatalog'
}
local_query_string = 'SELECT * FROM qt_gene_based LIMIT 50;'

# %%
# %%time
response = athena_client.start_query_execution(QueryString=local_query_string, QueryExecutionContext=context)
query_execution_id = response['QueryExecutionId']
#print('Execution ID: ', query_execution_id)
s3_path = wait_for_query_completion(athena_client, query_execution_id)
# Out:
# CPU times: user 18.9 ms, sys: 2.79 ms, total: 21.7 ms
# Wall time: 3.23 s

# %%
s3_path
# Out:
# 's3://aws-athena-query-results-638341270768-us-east-1/ef58b7b7-2621-4a8e-9293-d74213e802ce.csv'

# %%
file_name = re.findall('.*\/(.*)', s3_path)[0]
file_location = s3_path.replace('s3://','').split('/', 1)[0]
print('file name: ', file_name, 'file location: ', file_location)
# Out:
# file name:  ef58b7b7-2621-4a8e-9293-d74213e802ce.csv file location:  aws-athena-query-results-638341270768-us-east-1

# %%
s3_client = session.client('s3')
obj = s3_client.get_object(Bucket=file_location, Key=file_name)
result_df = pd.read_csv(io.BytesIO(obj['Body'].read()), header=0)
result_df
# Out:
#     chrom  genpos                                        id         mask  \
# 0       1  925926  SAMD11(ENSG00000187634).MASK_B.singleton  B.singleton
# 1       1  925926     SAMD11(ENSG00000187634).MASK_B.0.0001     B.0.0001
# 2       1  925926      SAMD11(ENSG00000187634).MASK_B.0.001      B.0.001
# 3       1  925926      SAMD11(ENSG00000187634).MASK_B.0.001      B.0.001
# 4       1  925926      SAMD11(ENSG00000187634).MASK_B.0.001      B.0.001
# 5       1  925926       SAMD11(ENSG00000187634).MASK_B.0.01       B.0.01
# 6       1  925926  SAMD11(ENSG00000187634).MASK_C.singleton  C.singleton
# 7       1  925926     SAMD11(ENSG00000187634).MASK_C.0.0001     C.0.0001
# 8       1  925926      SAMD11(ENSG00000187634).MASK_C.0.001      C.0.001
# 9       1  925926      SAMD11(ENSG00000187634).MASK_C.0.001      C.0.001
# 10      1  925926      SAMD11(ENSG00000187634).MASK_C.0.001      C.0.001
# 11      1  925926       SAMD11(ENSG00000187634).MASK_C.0.01       C.0.01
# 12      1  925926  SAMD11(ENSG00000187634).MASK_D.singleton  D.singleton
# 13      1  925926     SAMD11(ENSG00000187634).MASK_D.0.0001     D.0.0001
# 14      1  925926      SAMD11(ENSG00000187634).MASK_D.0.001      D.0.001
# 15      1  925926      SAMD11(ENSG00000187634).MASK_D.0.001      D.0.001
# 16      1  925926      SAMD11(ENSG00000187634).MASK_D.0.001      D.0.001
# 17      1  925926       SAMD11(ENSG00000187634).MASK_D.0.01       D.0.01
# 18      1  944699   NOC2L(ENSG00000188976).MASK_B.singleton  B.singleton
# 19      1  944699      NOC2L(ENSG00000188976).MASK_B.0.0001     B.0.0001
# 20      1  944699       NOC2L(ENSG00000188976).MASK_B.0.001      B.0.001
# 21      1  944699       NOC2L(ENSG00000188976).MASK_B.0.001      B.0.001
# 22      1  944699       NOC2L(ENSG00000188976).MASK_B.0.001      B.0.001
# 23      1  944699        NOC2L(ENSG00000188976).MASK_B.0.01       B.0.01
# 24      1  944699   NOC2L(ENSG00000188976).MASK_C.singleton  C.singleton
# 25      1  944699      NOC2L(ENSG00000188976).MASK_C.0.0001     C.0.0001
# 26      1  944699       NOC2L(ENSG00000188976).MASK_C.0.001      C.0.001
# 27      1  944699       NOC2L(ENSG00000188976).MASK_C.0.001      C.0.001
# 28      1  944699       NOC2L(ENSG00000188976).MASK_C.0.001      C.0.001
# 29      1  944699        NOC2L(ENSG00000188976).MASK_C.0.01       C.0.01
# 30      1  944699   NOC2L(ENSG00000188976).MASK_D.singleton  D.singleton
# 31      1  944699      NOC2L(ENSG00000188976).MASK_D.0.0001     D.0.0001
# 32      1  944699       NOC2L(ENSG00000188976).MASK_D.0.001      D.0.001
# 33      1  944699       NOC2L(ENSG00000188976).MASK_D.0.001      D.0.001
# 34      1  944699       NOC2L(ENSG00000188976).MASK_D.0.001      D.0.001
# 35      1  944699        NOC2L(ENSG00000188976).MASK_D.0.01       D.0.01
# 36      1  961299  KLHL17(ENSG00000187961).MASK_B.singleton  B.singleton
# 37      1  961299     KLHL17(ENSG00000187961).MASK_B.0.0001     B.0.0001
# 38      1  961299      KLHL17(ENSG00000187961).MASK_B.0.001      B.0.001
# 39      1  961299      KLHL17(ENSG00000187961).MASK_B.0.001      B.0.001
# 40      1  961299      KLHL17(ENSG00000187961).MASK_B.0.001      B.0.001
# 41      1  961299       KLHL17(ENSG00000187961).MASK_B.0.01       B.0.01
# 42      1  961299  KLHL17(ENSG00000187961).MASK_C.singleton  C.singleton
# 43      1  961299     KLHL17(ENSG00000187961).MASK_C.0.0001     C.0.0001
# 44      1  961299      KLHL17(ENSG00000187961).MASK_C.0.001      C.0.001
# 45      1  961299      KLHL17(ENSG00000187961).MASK_C.0.001      C.0.001
# 46      1  961299      KLHL17(ENSG00000187961).MASK_C.0.001      C.0.001
# 47      1  961299       KLHL17(ENSG00000187961).MASK_C.0.01       C.0.01
# 48      1  961299  KLHL17(ENSG00000187961).MASK_D.singleton  D.singleton
# 49      1  961299     KLHL17(ENSG00000187961).MASK_D.0.0001     D.0.0001
#
#       a1freq     n       test      beta        se     chisq  ...  \
# 0   0.003036  1153        ADD  0.363867  0.353264  1.060920  ...
# 1   0.003036  1153        ADD  0.363867  0.353264  1.060920  ...
# 2        NaN  1153   ADD-SKAT       NaN       NaN  0.074253  ...
# 3        NaN  1153  ADD-SKATO       NaN       NaN  0.074253  ...
# 4   0.003903  1153        ADD  0.085238  0.312806  0.074253  ...
# 5   0.009974  1153        ADD -0.055619  0.187779  0.087732  ...
# 6   0.007372  1153        ADD  0.328905  0.227895  2.082920  ...
# 7   0.007372  1153        ADD  0.328905  0.227895  2.082920  ...
# 8        NaN  1153   ADD-SKAT       NaN       NaN  0.646439  ...
# 9        NaN  1153  ADD-SKATO       NaN       NaN  0.646439  ...
# 10  0.012576  1153        ADD  0.141121  0.175520  0.646439  ...
# 11  0.033391  1153        ADD  0.020931  0.108133  0.037469  ...
# 12  0.006071  1153        ADD  0.087428  0.251327  0.121010  ...
# 13  0.006071  1153        ADD  0.087428  0.251327  0.121010  ...
# 14       NaN  1153   ADD-SKAT       NaN       NaN  0.267154  ...
# 15       NaN  1153  ADD-SKATO       NaN       NaN  0.267154  ...
# 16  0.008673  1153        ADD -0.108981  0.210848  0.267154  ...
# 17  0.021249  1153        ADD  0.018623  0.136802  0.018531  ...
# 18  0.002168  1153        ADD -0.421493  0.417472  1.019360  ...
# 19  0.002168  1153        ADD -0.421493  0.417472  1.019360  ...
# 20       NaN  1153   ADD-SKAT       NaN       NaN  1.019360  ...
# 21       NaN  1153  ADD-SKATO       NaN       NaN  1.019360  ...
# 22  0.002168  1153        ADD -0.421493  0.417472  1.019360  ...
# 23  0.003469  1153        ADD -0.613385  0.329567  3.464010  ...
# 24  0.009974  1153        ADD -0.160581  0.196926  0.664935  ...
# 25  0.009974  1153        ADD -0.160581  0.196926  0.664935  ...
# 26       NaN  1153   ADD-SKAT       NaN       NaN  0.347961  ...
# 27       NaN  1153  ADD-SKATO       NaN       NaN  0.347961  ...
# 28  0.012576  1153        ADD -0.103575  0.175586  0.347961  ...
# 29  0.027320  1153        ADD -0.006830  0.119629  0.003259  ...
# 30  0.003469  1153        ADD -0.221235  0.331840  0.444481  ...
# 31  0.003469  1153        ADD -0.221235  0.331840  0.444481  ...
# 32       NaN  1153   ADD-SKAT       NaN       NaN  0.047461  ...
# 33       NaN  1153  ADD-SKATO       NaN       NaN  0.047461  ...
# 34  0.004337  1153        ADD -0.064655  0.296781  0.047461  ...
# 35  0.035559  1153        ADD  0.041899  0.107995  0.150526  ...
# 36  0.002168  1153        ADD  0.149986  0.419297  0.127954  ...
# 37  0.002168  1153        ADD  0.149986  0.419297  0.127954  ...
# 38       NaN  1153   ADD-SKAT       NaN       NaN  0.384130  ...
# 39       NaN  1153  ADD-SKATO       NaN       NaN  0.384130  ...
# 40  0.003903  1153        ADD  0.194008  0.313026  0.384130  ...
# 41  0.006938  1153        ADD  0.035990  0.235605  0.023334  ...
# 42  0.004770  1153        ADD  0.156149  0.282833  0.304802  ...
# 43  0.004770  1153        ADD  0.156149  0.282833  0.304802  ...
# 44       NaN  1153   ADD-SKAT       NaN       NaN  0.011171  ...
# 45       NaN  1153  ADD-SKATO       NaN       NaN  0.011171  ...
# 46  0.008239  1153        ADD  0.022863  0.216315  0.011171  ...
# 47  0.015611  1153        ADD -0.027623  0.154264  0.032063  ...
# 48  0.005204  1153        ADD -0.039680  0.270492  0.021520  ...
# 49  0.005204  1153        ADD -0.039680  0.270492  0.021520  ...
#
#             gene id  variant mask       freq  \
# 0   ENSG00000187634             B  singleton
# 1   ENSG00000187634             B     0.0001
# 2   ENSG00000187634             B      0.001
# 3   ENSG00000187634             B      0.001
# 4   ENSG00000187634             B      0.001
# 5   ENSG00000187634             B       0.01
# 6   ENSG00000187634             C  singleton
# 7   ENSG00000187634             C     0.0001
# 8   ENSG00000187634             C      0.001
# 9   ENSG00000187634             C      0.001
# 10  ENSG00000187634             C      0.001
# 11  ENSG00000187634             C       0.01
# 12  ENSG00000187634             D  singleton
# 13  ENSG00000187634             D     0.0001
# 14  ENSG00000187634             D      0.001
# 15  ENSG00000187634             D      0.001
# 16  ENSG00000187634             D      0.001
# 17  ENSG00000187634             D       0.01
# 18  ENSG00000188976             B  singleton
# 19  ENSG00000188976             B     0.0001
# 20  ENSG00000188976             B      0.001
# 21  ENSG00000188976             B      0.001
# 22  ENSG00000188976             B      0.001
# 23  ENSG00000188976             B       0.01
# 24  ENSG00000188976             C  singleton
# 25  ENSG00000188976             C     0.0001
# 26  ENSG00000188976             C      0.001
# 27  ENSG00000188976             C      0.001
# 28  ENSG00000188976             C      0.001
# 29  ENSG00000188976             C       0.01
# 30  ENSG00000188976             D  singleton
# 31  ENSG00000188976             D     0.0001
# 32  ENSG00000188976             D      0.001
# 33  ENSG00000188976             D      0.001
# 34  ENSG00000188976             D      0.001
# 35  ENSG00000188976             D       0.01
# 36  ENSG00000187961             B  singleton
# 37  ENSG00000187961             B     0.0001
# 38  ENSG00000187961             B      0.001
# 39  ENSG00000187961             B      0.001
# 40  ENSG00000187961             B      0.001
# 41  ENSG00000187961             B       0.01
# 42  ENSG00000187961             C  singleton
# 43  ENSG00000187961             C     0.0001
# 44  ENSG00000187961             C      0.001
# 45  ENSG00000187961             C      0.001
# 46  ENSG00000187961             C      0.001
# 47  ENSG00000187961             C       0.01
# 48  ENSG00000187961             D  singleton
# 49  ENSG00000187961             D     0.0001
#
#                                              raw path phenotype stat  \
# 0   tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 1   tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 2   tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 3   tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 4   tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 5   tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 6   tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 7   tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 8   tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 9   tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 10  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 11  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 12  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 13  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 14  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 15  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 16  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 17  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 18  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 19  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 20  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 21  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 22  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 23  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 24  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 25  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 26  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 27  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 28  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 29  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 30  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 31  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 32  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 33  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 34  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 35  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 36  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 37  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 38  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 39  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 40  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 41  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 42  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 43  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 44  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 45  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 46  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 47  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 48  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
# 49  tak-insight-open-geneshealthconsort-silv/raw/2...       AFP  max
#
#    gene-based female-only male-only         label
# 0        True       False     False  AFP (burden)
# 1        True       False     False  AFP (burden)
# 2        True       False     False  AFP (burden)
# 3        True       False     False  AFP (burden)
# 4        True       False     False  AFP (burden)
# 5        True       False     False  AFP (burden)
# 6        True       False     False  AFP (burden)
# 7        True       False     False  AFP (burden)
# 8        True       False     False  AFP (burden)
# 9        True       False     False  AFP (burden)
# 10       True       False     False  AFP (burden)
# 11       True       False     False  AFP (burden)
# 12       True       False     False  AFP (burden)
# 13       True       False     False  AFP (burden)
# 14       True       False     False  AFP (burden)
# 15       True       False     False  AFP (burden)
# 16       True       False     False  AFP (burden)
# 17       True       False     False  AFP (burden)
# 18       True       False     False  AFP (burden)
# 19       True       False     False  AFP (burden)
# 20       True       False     False  AFP (burden)
# 21       True       False     False  AFP (burden)
# 22       True       False     False  AFP (burden)
# 23       True       False     False  AFP (burden)
# 24       True       False     False  AFP (burden)
# 25       True       False     False  AFP (burden)
# 26       True       False     False  AFP (burden)
# 27       True       False     False  AFP (burden)
# 28       True       False     False  AFP (burden)
# 29       True       False     False  AFP (burden)
# 30       True       False     False  AFP (burden)
# 31       True       False     False  AFP (burden)
# 32       True       False     False  AFP (burden)
# 33       True       False     False  AFP (burden)
# 34       True       False     False  AFP (burden)
# 35       True       False     False  AFP (burden)
# 36       True       False     False  AFP (burden)
# 37       True       False     False  AFP (burden)
# 38       True       False     False  AFP (burden)
# 39       True       False     False  AFP (burden)
# 40       True       False     False  AFP (burden)
# 41       True       False     False  AFP (burden)
# 42       True       False     False  AFP (burden)
# 43       True       False     False  AFP (burden)
# 44       True       False     False  AFP (burden)
# 45       True       False     False  AFP (burden)
# 46       True       False     False  AFP (burden)
# 47       True       False     False  AFP (burden)
# 48       True       False     False  AFP (burden)
# 49       True       False     False  AFP (burden)
#
# [50 rows x 23 columns]

# %% [markdown]
# ## Query for all results for a given gene (TYK2)

# %%
queryStringGene = 'SELECT * FROM qt_gene_based WHERE qt_gene_based."gene id"=\'ENSG00000105397\';'

# %%
# %%time
response = athena_client.start_query_execution(QueryString=queryStringGene, QueryExecutionContext=context)
query_execution_id = response['QueryExecutionId']
s3_path = wait_for_query_completion(athena_client, query_execution_id)
if not s3_path == 'FAILED':
    file_name = re.findall('.*\/(.*)', s3_path)[0]
    file_location = s3_path.replace('s3://','').split('/', 1)[0]
    obj = s3_client.get_object(Bucket=file_location, Key=file_name)
    result_df = pd.read_csv(io.BytesIO(obj['Body'].read()), header=0)
# Out:
# CPU times: user 616 ms, sys: 26.6 ms, total: 643 ms
# Wall time: 3min 20s

# %%
result_df
# Out:
#       chrom    genpos                                      id         mask  \
# 0        19  10350840  TYK2(ENSG00000105397).MASK_B.singleton  B.singleton
# 1        19  10350840     TYK2(ENSG00000105397).MASK_B.0.0001     B.0.0001
# 2        19  10350840      TYK2(ENSG00000105397).MASK_B.0.001      B.0.001
# 3        19  10350840      TYK2(ENSG00000105397).MASK_B.0.001      B.0.001
# 4        19  10350840      TYK2(ENSG00000105397).MASK_B.0.001      B.0.001
# ...     ...       ...                                     ...          ...
# 7303     19  10350840     TYK2(ENSG00000105397).MASK_D.0.0001     D.0.0001
# 7304     19  10350840      TYK2(ENSG00000105397).MASK_D.0.001      D.0.001
# 7305     19  10350840      TYK2(ENSG00000105397).MASK_D.0.001      D.0.001
# 7306     19  10350840      TYK2(ENSG00000105397).MASK_D.0.001      D.0.001
# 7307     19  10350840       TYK2(ENSG00000105397).MASK_D.0.01       D.0.01
#
#         a1freq      n       test      beta        se     chisq  ...  \
# 0     0.006505   1153        ADD -0.279340  0.251489  1.233760  ...
# 1     0.006505   1153        ADD -0.279340  0.251489  1.233760  ...
# 2          NaN   1153   ADD-SKAT       NaN       NaN  0.245660  ...
# 3          NaN   1153  ADD-SKATO       NaN       NaN  0.245660  ...
# 4     0.008239   1153        ADD -0.110291  0.222521  0.245660  ...
# ...        ...    ...        ...       ...       ...       ...  ...
# 7303  0.002020  15843        ADD  0.018873  0.120692  0.024452  ...
# 7304       NaN  15843   ADD-SKAT       NaN       NaN  0.409387  ...
# 7305       NaN  15843  ADD-SKATO       NaN       NaN  0.227166  ...
# 7306  0.008647  15843        ADD -0.041688  0.057690  0.522176  ...
# 7307  0.035158  15843        ADD -0.009734  0.029621  0.107994  ...
#
#               gene id  variant mask       freq  \
# 0     ENSG00000105397             B  singleton
# 1     ENSG00000105397             B     0.0001
# 2     ENSG00000105397             B      0.001
# 3     ENSG00000105397             B      0.001
# 4     ENSG00000105397             B      0.001
# ...               ...           ...        ...
# 7303  ENSG00000105397             D     0.0001
# 7304  ENSG00000105397             D      0.001
# 7305  ENSG00000105397             D      0.001
# 7306  ENSG00000105397             D      0.001
# 7307  ENSG00000105397             D       0.01
#
#                                                raw path            phenotype  \
# 0     tak-insight-open-geneshealthconsort-silv/raw/2...                  AFP
# 1     tak-insight-open-geneshealthconsort-silv/raw/2...                  AFP
# 2     tak-insight-open-geneshealthconsort-silv/raw/2...                  AFP
# 3     tak-insight-open-geneshealthconsort-silv/raw/2...                  AFP
# 4     tak-insight-open-geneshealthconsort-silv/raw/2...                  AFP
# ...                                                 ...                  ...
# 7303  tak-insight-open-geneshealthconsort-silv/raw/2...  Waist_circumference
# 7304  tak-insight-open-geneshealthconsort-silv/raw/2...  Waist_circumference
# 7305  tak-insight-open-geneshealthconsort-silv/raw/2...  Waist_circumference
# 7306  tak-insight-open-geneshealthconsort-silv/raw/2...  Waist_circumference
# 7307  tak-insight-open-geneshealthconsort-silv/raw/2...  Waist_circumference
#
#      stat gene-based female-only male-only                         label
# 0     max       True       False     False                  AFP (burden)
# 1     max       True       False     False                  AFP (burden)
# 2     max       True       False     False                  AFP (burden)
# 3     max       True       False     False                  AFP (burden)
# 4     max       True       False     False                  AFP (burden)
# ...   ...        ...         ...       ...                           ...
# 7303  min       True       False     False  Waist circumference (burden)
# 7304  min       True       False     False  Waist circumference (burden)
# 7305  min       True       False     False  Waist circumference (burden)
# 7306  min       True       False     False  Waist circumference (burden)
# 7307  min       True       False     False  Waist circumference (burden)
#
# [7308 rows x 23 columns]

# %% [markdown]
# ## Query for all signigicant burden associations for a given gene (SERPINA1)

# %%
queryStringGene = 'SELECT * FROM qt_gene_based WHERE qt_gene_based."gene id"=\'ENSG00000197249\' AND qt_gene_based.significant = true;'

# %%
# %%time
response = athena_client.start_query_execution(QueryString=queryStringGene, QueryExecutionContext=context)
query_execution_id = response['QueryExecutionId']
s3_path = wait_for_query_completion(athena_client, query_execution_id)
if not s3_path == 'FAILED':
    file_name = re.findall('.*\/(.*)', s3_path)[0]
    file_location = s3_path.replace('s3://','').split('/', 1)[0]
    obj = s3_client.get_object(Bucket=file_location, Key=file_name)
    result_df = pd.read_csv(io.BytesIO(obj['Body'].read()), header=0)
# Out:
# CPU times: user 390 ms, sys: 15.4 ms, total: 405 ms
# Wall time: 3min 30s

# %%
result_df
# Out:
# Empty DataFrame
# Columns: [chrom, genpos, id, mask, a1freq, n, test, beta, se, chisq, log10p, significant, gene symbol, gene id, variant mask, freq, raw path, phenotype, stat, gene-based, female-only, male-only, label]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ## Query for all single variant associations within the genomic region of a given gene (TYK2)

# %%
queryStringGene = 'SELECT * FROM qt_single_variant WHERE qt_single_variant.chrom = 19 AND qt_single_variant.genpos < 10380608 AND qt_single_variant.genpos > 10350533;'

# %%
# %%time
response = athena_client.start_query_execution(QueryString=queryStringGene, QueryExecutionContext=context)
query_execution_id = response['QueryExecutionId']
s3_path = wait_for_query_completion(athena_client, query_execution_id)
if not s3_path == 'FAILED':
    file_name = re.findall('.*\/(.*)', s3_path)[0]
    file_location = s3_path.replace('s3://','').split('/', 1)[0]
    obj = s3_client.get_object(Bucket=file_location, Key=file_name)
    result_df = pd.read_csv(io.BytesIO(obj['Body'].read()), header=0)
# Out:
# CPU times: user 1.11 s, sys: 62.9 ms, total: 1.17 s
# Wall time: 8min 40s

# %%
result_df
# Out:
#        chrom    genpos                  id allele0 allele1    a1freq      n  \
# 0         19  10350843  chr19_10350843_G_A       G       A  0.002098  13584
# 1         19  10350910  chr19_10350910_T_C       T       C  0.017005  13584
# 2         19  10351069  chr19_10351069_C_T       C       T  0.000221  13584
# 3         19  10351070  chr19_10351070_G_A       G       A  0.001031  13584
# 4         19  10351109  chr19_10351109_G_C       G       C  0.000994  13584
# ...      ...       ...                 ...     ...     ...       ...    ...
# 40063     19  10378350  chr19_10378350_G_A       G       A  0.000726  15843
# 40064     19  10378363  chr19_10378363_A_G       A       G  0.005144  15843
# 40065     19  10378365  chr19_10378365_G_A       G       A  0.001168  15843
# 40066     19  10378371  chr19_10378371_A_C       A       C  0.000379  15843
# 40067     19  10378397  chr19_10378397_G_A       G       A  0.001515  15843
#
#       test      beta        se     chisq    log10p  significant  \
# 0      ADD  0.008030  0.125962  0.004064  0.022655        False
# 1      ADD -0.037337  0.044208  0.713312  0.399739        False
# 2      ADD -0.029673  0.387217  0.005872  0.027373        False
# 3      ADD  0.062226  0.179512  0.120158  0.137354        False
# 4      ADD -0.206436  0.176301  1.371080  0.616854        False
# ...    ...       ...       ...       ...       ...          ...
# 40063  ADD -0.437253  0.192884  5.138910  1.630870        False
# 40064  ADD  0.054369  0.075027  0.525128  0.329140        False
# 40065  ADD  0.098673  0.158914  0.385544  0.271930        False
# 40066  ADD -0.205617  0.257894  0.635678  0.371325        False
# 40067  ADD  0.138431  0.139336  0.987052  0.494221        False
#
#                                                 raw path            phenotype  \
# 0      tak-insight-open-geneshealthconsort-silv/raw/2...                  AST
# 1      tak-insight-open-geneshealthconsort-silv/raw/2...                  AST
# 2      tak-insight-open-geneshealthconsort-silv/raw/2...                  AST
# 3      tak-insight-open-geneshealthconsort-silv/raw/2...                  AST
# 4      tak-insight-open-geneshealthconsort-silv/raw/2...                  AST
# ...                                                  ...                  ...
# 40063  tak-insight-open-geneshealthconsort-silv/raw/2...  Waist_circumference
# 40064  tak-insight-open-geneshealthconsort-silv/raw/2...  Waist_circumference
# 40065  tak-insight-open-geneshealthconsort-silv/raw/2...  Waist_circumference
# 40066  tak-insight-open-geneshealthconsort-silv/raw/2...  Waist_circumference
# 40067  tak-insight-open-geneshealthconsort-silv/raw/2...  Waist_circumference
#
#       stat  gene-based  female-only  male-only                label
# 0      max       False        False      False                  AST
# 1      max       False        False      False                  AST
# 2      max       False        False      False                  AST
# 3      max       False        False      False                  AST
# 4      max       False        False      False                  AST
# ...    ...         ...          ...        ...                  ...
# 40063  min       False        False      False  Waist circumference
# 40064  min       False        False      False  Waist circumference
# 40065  min       False        False      False  Waist circumference
# 40066  min       False        False      False  Waist circumference
# 40067  min       False        False      False  Waist circumference
#
# [40068 rows x 20 columns]

# %%
athena_client.close()
s3_client.close()
